# %%
import sys, os
sys.path.append(os.path.abspath(".."))
from src.preprocessing import preprocess_text_fin
import pandas as pd
import pickle
# Load pipeline
with open("../models/Naive_Bayes/NB_model.pkl", "rb") as f:
    best_loaded = pickle.load(f)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\hung0\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\hung0\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
# Thử dự đoán
test_sentences = [
    "Bank of England cuts rates to 4% after narrow 5-4 vote",
    "Dollar shedding its tariff risk premium",
    "Sabadell's CEO says sale of TSB would complicate BBVA's bid for lender",
    "ECB should keep rates at 2% unless new shocks hit, IMF says",
    "No scope for rate cuts with inflation outside tolerance band, Hungary central banker says",
    "Morning Bid: Deadline? What deadline?",
    "Sterling nudges lower but still near multi-year highs, looking past UK politics",
    "ECB should consider mildly supportive stance as on low growth, inflation, Wunsch says",
    "Italy could lose 20 bln euros in exports, 118,000 jobs with US tariffs, industry head says",
    "Joint European defence borrowing could bolster euro's global role, ECB's Rehn says",
    "Italy May unemployment rate jumps to 6.5% but 80,000 jobs created in month",
    "Santander bolsters presence in UK with acquisition of TSB for $3.64 billion",
    "DWS venture gets German finance regulator's approval for euro stablecoin",
    "Spain's Zelestra gains an extra $280 million in financing for renewable energy projects",
    "Morning Bid: Markets sit tight for trade progress",
    "Stocks slip, US yields rise as data, Powell comments gauged",
    "Spain and World Bank in push for wider use of 'debt swaps'",
    "Dollar pares losses against euro and Swiss franc after better-than-expected US jobs data",
    "Foreign investors increase dollar hedges on US stock portfolios",
    "Euro zone factory orders stabilise for first time in 3 years, PMI shows",
    "European shares end marginally lower as markets gauge trade talks, US tax bill",
    "Challenge to dollar supremacy a long way off, central bankers say",
    "Euro zone inflation picks up to ECB target",
    "Norway's Euro players unbothered by heatwave as Swiss temperatures soar",
    "BNP Paribas completes AXA IM acquisition, in talks with supervisors on capital hit",
    "ECB's Lagarde says euro's rise also reflects economic strength",
    "Tariff risks muddy global outlook for factories",
    "ECB can afford to hold off on further rate changes for a while, Müller says",
    "Sterling firms to three-year peak, focus on welfare bill vote",
    "BlackRock eyes shorter-term bets amid shaky global economic foundations",
    "Morning Bid: Senate's vote-a-rama continues",
    "ECB policymakers set pain threshold for euro rise in weak economy",
    "Greece to present plan to settle Swiss franc mortgage dispute, sources say",
    "Mood in Germany's chemical industry brightens on power subsidy plan, Ifo says",
    "ECB more likely to wait until year-end to cut rates, Simkus says",
    "Morning Bid: Uncertainty dominates ECB forum",
    "Stocks hit fresh record on trade optimism, dollar falls",
    "BBVA to proceed with Sabadell bid despite government condition",
    "Trading Day: Ending first half on a record high note"
]

# Tiền xử lý trước khi dự đoán
test_clean_list = [preprocess_text_fin(s) for s in test_sentences]

pred_labels = best_loaded.predict(test_clean_list)
pred_probas = best_loaded.predict_proba(test_clean_list)

# Tạo DataFrame kết quả
df_results = pd.DataFrame({
    "Original": test_sentences,
    # "Cleaned": test_clean_list,
    "Pred_Label": pred_labels,
    "Pred_Prob": [f"{max(p)*100:.2f}%" for p in pred_probas]
})

# In ra dạng bảng gọn đẹp
pd.set_option("display.max_colwidth", 200)
df_results
# Out:
#                                                                                       Original  \
# 0                                       Bank of England cuts rates to 4% after narrow 5-4 vote
# 1                                                      Dollar shedding its tariff risk premium
# 2                       Sabadell's CEO says sale of TSB would complicate BBVA's bid for lender
# 3                                  ECB should keep rates at 2% unless new shocks hit, IMF says
# 4    No scope for rate cuts with inflation outside tolerance band, Hungary central banker says
# 5                                                        Morning Bid: Deadline? What deadline?
# 6              Sterling nudges lower but still near multi-year highs, looking past UK politics
# 7        ECB should consider mildly supportive stance as on low growth, inflation, Wunsch says
# 8   Italy could lose 20 bln euros in exports, 118,000 jobs with US tariffs, industry head says
# 9           Joint European defence borrowing could bolster euro's global role, ECB's Rehn says
# 10                  Italy May unemployment rate jumps to 6.5% but 80,000 jobs created in month
# 11                 Santander bolsters presence in UK with acquisition of TSB for $3.64 billion
# 12                    DWS venture gets German finance regulator's approval for euro stablecoin
# 13     Spain's Zelestra gains an extra $280 million in financing for renewable energy projects
# 14                                           Morning Bid: Markets sit tight for trade progress
# 15                                 Stocks slip, US yields rise as data, Powell comments gauged
# 16                                  Spain and World Bank in push for wider use of 'debt swaps'
# 17    Dollar pares losses against euro and Swiss franc after better-than-expected US jobs data
# 18                             Foreign investors increase dollar hedges on US stock portfolios
# 19                     Euro zone factory orders stabilise for first time in 3 years, PMI shows
# 20              European shares end marginally lower as markets gauge trade talks, US tax bill
# 21                           Challenge to dollar supremacy a long way off, central bankers say
# 22                                                  Euro zone inflation picks up to ECB target
# 23                     Norway's Euro players unbothered by heatwave as Swiss temperatures soar
# 24          BNP Paribas completes AXA IM acquisition, in talks with supervisors on capital hit
# 25                              ECB's Lagarde says euro's rise also reflects economic strength
# 26                                             Tariff risks muddy global outlook for factories
# 27                 ECB can afford to hold off on further rate changes for a while, Müller says
# 28                               Sterling firms to three-year peak, focus on welfare bill vote
# 29                     BlackRock eyes shorter-term bets amid shaky global economic foundations
# 30                                                 Morning Bid: Senate's vote-a-rama continues
# 31                           ECB policymakers set pain threshold for euro rise in weak economy
# 32                  Greece to present plan to settle Swiss franc mortgage dispute, sources say
# 33               Mood in Germany's chemical industry brightens on power subsidy plan, Ifo says
# 34                            ECB more likely to wait until year-end to cut rates, Simkus says
# 35                                                Morning Bid: Uncertainty dominates ECB forum
# 36                                     Stocks hit fresh record on trade optimism, dollar falls
# 37                              BBVA to proceed with Sabadell bid despite government condition
# 38                                        Trading Day: Ending first half on a record high note
#
#    Pred_Label Pred_Prob
# 0    negative    44.33%
# 1    negative    39.98%
# 2    positive    57.01%
# 3    positive    47.27%
# 4     neutral    50.53%
# 5    positive    59.86%
# 6    negative    46.16%
# 7    positive    53.93%
# 8     neutral    40.93%
# 9     neutral    55.28%
# 10   positive    42.46%
# 11   positive    75.23%
# 12   positive    47.25%
# 13   positive    46.11%
# 14   positive    72.63%
# 15   positive    53.35%
# 16   positive    54.02%
# 17   negative    62.08%
# 18   positive    39.02%
# 19   positive    39.68%
# 20    neutral    55.91%
# 21   positive    47.33%
# 22   positive    48.33%
# 23    neutral    46.58%
# 24   positive    45.26%
# 25   positive    55.88%
# 26    neutral    48.07%
# 27    neutral    43.14%
# 28   positive    44.06%
# 29   positive    49.57%
# 30   positive    45.43%
# 31   negative    39.40%
# 32   positive    42.77%
# 33    neutral    54.57%
# 34    neutral    40.67%
# 35   negative    42.18%
# 36   negative    72.28%
# 37    neutral    44.97%
# 38   negative    50.46%
